# %%
# !git clone 'https://github.com/vishalsharma3003/av_deepfake_detection.git'
# Out:
# Cloning into 'av_deepfake_detection'...
# remote: Enumerating objects: 73, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 73 (delta 15), reused 44 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (73/73), 83.57 KiB | 684.00 KiB/s, done.
# Resolving deltas: 100% (15/15), done.

# %%
# !mkdir ../root/.kaggle/
# !echo '{"username":"yourusername","key":"yourkey"}' >> /root/.kaggle/kaggle.json
# !chmod 400 ../root/.kaggle/kaggle.json  #Read-only
# !cat ../root/.kaggle/kaggle.json
# Out:
# {"username":"yourusername","key":"yourkey"}

# %%
# !kaggle datasets download -d vishalsharma3003/multimodal-pretrained
# Out:
# Dataset URL: https://www.kaggle.com/datasets/vishalsharma3003/multimodal-pretrained
# License(s): CC0-1.0
# ...
#  96% 287M/300M [00:02<00:00, 141MB/s]
# 100% 300M/300M [00:02<00:00, 121MB/s]

# %%
# !unzip '/content/multimodal-pretrained.zip' -d '/content/av_deepfake_detection/downloads'
# Out:
# unzip:  cannot find or open /content/multimodal_pretrained_models.zip, /content/multimodal_pretrained_models.zip.zip or /content/multimodal_pretrained_models.zip.ZIP.

# %%
# !kaggle datasets download -d vishalsharma3003/fakeacvelebtfrecord
# Out:
# Dataset URL: https://www.kaggle.com/datasets/vishalsharma3003/fakeacvelebtfrecord
# License(s): MIT
# ...
#  99% 1.54G/1.55G [00:13<00:00, 240MB/s]
# 100% 1.55G/1.55G [00:13<00:00, 120MB/s]

# %%
# !unzip -q '/content/fakeacvelebtfrecord.zip' -d inputs/

# %%
# !pip install -r '/content/av_deepfake_detection/requirements.txt'

for i in range(9):
  # !cp '/content/inputs/fakeavceleb_1k-0000{i}-of-00015' '/content/av_deepfake_detection/datasets/train'


for i in range(10, 15):
  # !cp '/content/inputs/fakeavceleb_1k-000{i}-of-00015' '/content/av_deepfake_detection/datasets/train'
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=2d69ba3197d12bf590fb0708677d2fed4b630019c0472fce9b57cad77414788b
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# ...
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6082 sha256=1362d34307974571364d6c63ac9e575287ea9c4916f1562c66887564492eb80f
#   Stored in directory: /root/.cache/pip/wheels/8e/7a/69/cd6aeb83b126a7f04cbe7c9d929028dc52a6e7d525ff56003a
# Successfully built wget ffmpeg
# ...

# %%
# !python '/content/av_deepfake_detection/main.py' --device='cuda' \
  --data_dir="/content/inputs/inputs/fakeavceleb_1k*" \
  --pretrained_image_encoder=True --pretrained_audio_encoder=False \
  --batch_size=2 --freeze_image_encoder=True --freeze_audio_encoder=True \
  --augment_dataset=True --lr=2e-5 --max_epochs=50
